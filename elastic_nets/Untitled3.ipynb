# %%
import pandas
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
# %matplotlib inline

kinetics = pandas.read_csv( '/Users/alex/Documents/bagel/data/data_clean.csv' )
plt.scatter( kinetics.s, kinetics.maxv * 1000, alpha=0.3, color='magenta' )
#plt.yscale( 'log' )
kinetics.dropna( inplace=True )
samples = kinetics.groupby( 'sample' )

print [ name for name, df in samples ]
print kinetics.columns

def f( x, kcat, km ):
    return ( kcat * x ) / ( km + x )

def calc_y( df ):
    popt, pcov = curve_fit( f, df.s, df.maxv, p0=( df.maxv.max(), df.s.mean() ) )
    return
# Out:
# ['a192s', 'c167a', 'c167n+w120r', 'c167q', 'd403a', 'e154d', 'e164a', 'e177a', 'e177k', 'e177l', 'e17s', 'e222a', 'e222h', 'e222k', 'e222q', 'e222r', 'e222y', 'e353a', 'e406a', 'e406d', 'e423s', 'f405a', 'f415a', 'f75a', 'g355a', 'h101r', 'h119a', 'h119e', 'h119n', 'h178a', 'h315n', 'h373r', 'h379r', 'i244e', 'i244n', 'i300n', 'i91e', 'k341a', 'k413a', 'l171a', 'l171r', 'l219a', 'm221a', 'm223g', 'm261e', 'm323a', 'm323k', 'm358t', 'n163a', 'n163c', 'n163d', 'n220a', 'n220d+n293d', 'n220h', 'n293a', 'n354a', 'n404a', 'n407a', 'p329w', 'q19a', 'q19c', 'q19s', 'q284r', 'q313r', 'r240a', 'r240d', 'r240k', 'r76a', 's14a', 's16a', 's17a', 's298e', 's331a', 's400a', 't175r', 't218a', 't296a', 't352a', 'v147s', 'v52g', 'w120a', 'w120f', 'w120h', 'w325a', 'w325c', 'w325h', 'w325l', 'w34a', 'w399a', 'w399c', 'w399g', 'w399s', 'w407a', 'w407g', 'w407q', 'w407r', 'w409a', 'y166p', 'y18a', 'y294a', 'y294f', 'y295a', 'y295g']
# ...

# %%
samples.apply( calc_y )
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /usr/local/bin/anaconda/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     695                 type_pprinters=self.type_printers,
#     696                 deferred_pprinters=self.deferred_printers)
# --> 697             printer.pretty(obj)
#     698             printer.flush()
#     699             return stream.getvalue()
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/IPython/lib/pretty.pyc in pretty(self, obj)
#     381                             if callable(meth):
#     382                                 return meth(obj, self, cycle)
# --> 383             return _default_pprint(obj, self, cycle)
#     384         finally:
#     385             self.end_group()
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/IPython/lib/pretty.pyc in _default_pprint(obj, p, cycle)
# ...
